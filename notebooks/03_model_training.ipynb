# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
import pandas as pd
from src.train_model import *
import joblib

# %%
MODEL_PATH = "../models/"

# load data
PATH = "../data/"
train_df = pd.read_csv(PATH + "train_msmes_data.csv")

# fit data
pipeline = train_model(train_df)

joblib.dump(pipeline, MODEL_PATH+"financial_health_xgboost_pipeline.pkl")
# Out:
# 2026-07-07 20:21:49 - INFO - Negative samples: 14290
# 2026-07-07 20:21:49 - INFO - Positive samples: 1710
# 2026-07-07 20:21:49 - INFO - scale_pos_weight: 8.36
# 2026-07-07 20:21:49 - INFO - Training XGBoost model...
# 2026-07-07 20:21:50 - INFO - Model training completed successfully.
# ['../models/financial_health_xgboost_pipeline.pkl']
