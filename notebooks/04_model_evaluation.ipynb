# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
import pandas as pd
import joblib
from src.evaluate import *

# %%
# Load data
PATH = "../data/"
test_df = pd.read_csv(PATH + "train_msmes_data.csv")

#load pipeline
PIPELINE_FILE = "../models/financial_health_xgboost_pipeline.pkl"
pipeline = joblib.load(PIPELINE_FILE)

metrics = evaluate_model(pipeline, test_df)
metrics
# Out:
# 2026-07-07 20:22:12 - INFO - Model evaluation completed.
# {'Accuracy': 0.9351875,
#  'Precision': 0.627029067572669,
#  'Recall': 0.9713450292397661,
#  'F1 Score': 0.7621013994035329,
#  'ROC-AUC': 0.988759448188935}

# %%
plot_confusion_matrix(pipeline, test_df)

# %%
plot_roc_pr_curves(pipeline, test_df)
# Out:
# {'ROC-AUC': 0.988759448188935, 'PR-AUC': 0.9154769494391393}
